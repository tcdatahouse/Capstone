# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify duplicate values in the dataset.
#
# *   Remove duplicate values from the dataset.
#
# *   Identify missing values in the dataset.
#
# *   Impute the missing values in the dataset.
#
# *   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/Capstone_edX/Module%201/survey_results_public_2020.csv")

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %% [markdown]
# #Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
# Find how many duplicate rows exist in the dataframe.

# %%
# Identify duplicate rows in dataframe
duplicate = df[df.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [Respondent, MainBranch, Hobbyist, Age, Age1stCode, CompFreq, CompTotal, ConvertedComp, Country, CurrencyDesc, CurrencySymbol, DatabaseDesireNextYear, DatabaseWorkedWith, DevType, EdLevel, Employment, Ethnicity, Gender, JobFactors, JobSat, JobSeek, LanguageDesireNextYear, LanguageWorkedWith, MiscTechDesireNextYear, MiscTechWorkedWith, NEWCollabToolsDesireNextYear, NEWCollabToolsWorkedWith, NEWDevOps, NEWDevOpsImpt, NEWEdImpt, NEWJobHunt, NEWJobHuntResearch, NEWLearn, NEWOffTopic, NEWOnboardGood, NEWOtherComms, NEWOvertime, NEWPurchaseResearch, NEWPurpleLink, NEWSOSites, NEWStuck, OpSys, OrgSize, PlatformDesireNextYear, PlatformWorkedWith, PurchaseWhat, Sexuality, SOAccount, SOComm, SOPartFreq, SOVisitFreq, SurveyEase, SurveyLength, Trans, UndergradMajor, WebframeDesireNextYear, WebframeWorkedWith, WelcomeChange, WorkWeekHrs, YearsCode, YearsCodePro]
# Index: []

# %%
len(duplicate)
# Out:
# 0

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
#Remove duplicate rows and create new dataframe
df2 = df
df2.drop_duplicates(inplace = True)

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# Identify duplicate rows in dataframe (secondary check)
duplicateCheckQty = df2[df2.duplicated()]
duplicateCheckQty
# Out:
# Empty DataFrame
# Columns: [Respondent, MainBranch, Hobbyist, Age, Age1stCode, CompFreq, CompTotal, ConvertedComp, Country, CurrencyDesc, CurrencySymbol, DatabaseDesireNextYear, DatabaseWorkedWith, DevType, EdLevel, Employment, Ethnicity, Gender, JobFactors, JobSat, JobSeek, LanguageDesireNextYear, LanguageWorkedWith, MiscTechDesireNextYear, MiscTechWorkedWith, NEWCollabToolsDesireNextYear, NEWCollabToolsWorkedWith, NEWDevOps, NEWDevOpsImpt, NEWEdImpt, NEWJobHunt, NEWJobHuntResearch, NEWLearn, NEWOffTopic, NEWOnboardGood, NEWOtherComms, NEWOvertime, NEWPurchaseResearch, NEWPurpleLink, NEWSOSites, NEWStuck, OpSys, OrgSize, PlatformDesireNextYear, PlatformWorkedWith, PurchaseWhat, Sexuality, SOAccount, SOComm, SOPartFreq, SOVisitFreq, SurveyEase, SurveyLength, Trans, UndergradMajor, WebframeDesireNextYear, WebframeWorkedWith, WelcomeChange, WorkWeekHrs, YearsCode, YearsCodePro]
# Index: []

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# Find any values are missing in each column
pd.set_option("display.max_rows", None, "display.max_columns", None)
missingValues = df2.isnull().any()
missingValues
# Out:
# Respondent                      False
# MainBranch                       True
# Hobbyist                         True
# Age                              True
# Age1stCode                       True
# CompFreq                         True
# CompTotal                        True
# ConvertedComp                    True
# Country                          True
# CurrencyDesc                     True
# CurrencySymbol                   True
# DatabaseDesireNextYear           True
# DatabaseWorkedWith               True
# DevType                          True
# EdLevel                          True
# Employment                       True
# Ethnicity                        True
# Gender                           True
# JobFactors                       True
# JobSat                           True
# JobSeek                          True
# LanguageDesireNextYear           True
# LanguageWorkedWith               True
# MiscTechDesireNextYear           True
# MiscTechWorkedWith               True
# ...

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
# identify quantity of missing values in 'WorkLoc' column
missingValuesCounts = df2.isnull().sum()
missingValuesCounts
# Out:
# Respondent                          0
# MainBranch                        299
# Hobbyist                           45
# Age                             19015
# Age1stCode                       6561
# CompFreq                        24392
# CompTotal                       29635
# ConvertedComp                   29705
# Country                           389
# CurrencyDesc                    18989
# CurrencySymbol                  18989
# DatabaseDesireNextYear          20391
# DatabaseWorkedWith              14924
# DevType                         15091
# EdLevel                          7030
# Employment                        607
# Ethnicity                       18513
# Gender                          13904
# JobFactors                      15112
# JobSat                          19267
# JobSeek                         12734
# LanguageDesireNextYear          10348
# LanguageWorkedWith               7083
# MiscTechDesireNextYear          22082
# MiscTechWorkedWith              24147
# ...

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column Age.

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
# your code goes here
ageValues = (df2['Age'].value_counts())
# Out:
# 25.0     2693
# 28.0     2412
# 30.0     2406
# 26.0     2391
# 27.0     2338
# 24.0     2275
# 29.0     2219
# 23.0     2213
# 22.0     1884
# 32.0     1781
# 31.0     1716
# 21.0     1628
# 33.0     1527
# 35.0     1485
# 34.0     1374
# 20.0     1204
# 36.0     1129
# 38.0     1094
# 37.0     1057
# 40.0      914
# 39.0      858
# 19.0      816
# 18.0      644
# 42.0      626
# 41.0      591
# 43.0      520
# 45.0      472
# 17.0      422
# 44.0      397
# 46.0      348
# 48.0      341
# 16.0      326
# 49.0      306
# 47.0      298
# 50.0      292
# 15.0      231
# 51.0      211
# 52.0      205
# 55.0      185
# 53.0      172
# 54.0      161
# 56.0      124
# 57.0      118
# 14.0      111
# 58.0      102
# 59.0       94
# 60.0       88
# 63.0       76
# 61.0       67
# 13.0       63
# 62.0       60
# 66.0       43
# 64.0       43
# 65.0       36
# 67.0       25
# 69.0       23
# 12.0       23
# 70.0       19
# 68.0       18
# 72.0       18
# 71.0       15
# 73.0       14
# ...

# %% [markdown]
# Find the median for the column Age

# %%
pd.reset_option("display.max_rows")
# determine median age of respondents
medianAgeValues = df2['Age'].median()
medianAgeValues
# Out:
# 29.0

# %% [markdown]
# Impute the median value to Age column

# %%
# Replace empty values in a column with another string value
df2[['Age']] = df2[['Age']].fillna(medianAgeValues)

# %%
# determine median age of respondents
xmedianAgeValues = df2['Age'].median()
xmedianAgeValues
# Out:
# 29.0

# %% [markdown]
# Identify the value that is most frequent (majority) in the Country column.

# %%
countryValues = df2['Country'].value_counts()
countryValues.head(1)
# Out:
# United States    12469
# Name: Country, dtype: int64

# %% [markdown]
# Drop all the missing values from the dataset

# %%
# your code goes here

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# Determine values existing in 'CompFreq' column, and determine quanity of each
compFrequencyCount = df2['CompFreq'].value_counts()
compFrequencyCount
# Out:
# Yearly     19818
# Monthly    18899
# Weekly      1352
# Name: CompFreq, dtype: int64

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# Add 'NormalizedAnnualCompensation' column, and calculate annual salary, based on different pay frequencies 
import numpy as np 
df2['NormalizedAnnualCompensation'] = np.where(
    df2['CompFreq'] == 'Weekly', df2['CompTotal']*52, np.where(
    df2['CompFreq'] == 'Monthly', df2['CompTotal']*12, df2['CompTotal']))
df2.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0  29.0         13  Monthly        NaN            NaN             Germany
# 1  29.0         19      NaN        NaN            NaN      United Kingdom
# 2  29.0         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
